# %% [markdown]
# Exercise 1: Identifying Data Types
#
# A company’s financial reports stored in an Excel file. - Structred Data
# Photographs uploaded to a social media platform. - Unstrctred Data
# A collection of news articles on a website. - Unstructured Data
# Inventory data in a relational database. - Structred Data
# Recorded interviews from a market research study. - Unstructred Data

# %% [markdown]
# Exercise 2: Transformation Exercise
#
#
# A series of blog posts about travel experiences
# I would read through the posts and pick out the important details like where the person traveled to, what they did, and when. I’d then put that into a table so each blog has a destination, activity, and date.
#
# Audio recordings of customer service calls
# I would listen to each call and write down the main issue the customer had, group it into a category (like billing, technical, complaint), and also note if the issue was resolved or not.
#
# Handwritten notes from a brainstorming session
# I would type out the notes and then sort the ideas into categories such as marketing, product features, or challenges. That way each idea is clear and organized.
#
# A video tutorial on cooking
# I would watch the video and write down each cooking step in order, including the ingredients needed and the time it takes. This way it becomes a recipe that’s easy to follow.

# %%
import pandas as pd

# %%
df = pd.read_csv("train (1).csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd
df = pd.read_csv("Iris_dataset.csv")
df.head(5)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "Los Angeles", "Chicago"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df.to_excel("new_dataset.xlsx", index=False)

# %%
df.to_json("new_dataset.json", orient="records", indent=4)

# %%
import pandas as pd
df = pd.read_json("posts.json")
print(df.head())
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
