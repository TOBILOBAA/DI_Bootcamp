# %% [markdown]
# Data Visualisation is important in data analysis because it helps summaries huge dataset making it easier to illustrate and read the data.
#
# Line graph in data visualisation helps show trend over a given period.

# %%
import pandas as pd
import matplotlib.pyplot as plt

Temperature = [72, 74, 76, 80, 82, 78, 75]
Day = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

plt.plot(Day, Temperature)
plt.title('Temperature Graph')
plt.xlabel('Day')
plt.ylabel('Temperature(°F)')
plt.show()

# %% [markdown]
# Objective: Generate a bar chart using Matplotlib to visualize monthly sales data for a retail store.
# Tasks:
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]).
# Label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.
# Add a title to the bar chart.
# Display the plot.

# %%
Month = ['January', 'February', 'March', 'April', 'May']
Sales_Amount = [5000, 5500, 6200, 7000, 7500]

plt.bar(Month,Sales_Amount)
plt.title("Monthly Sales Data")
plt.xlabel("Month")
plt.ylabel("Sales_Amount")
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b619398a-6de8-4129-912c-361040f6d66a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b619398a-6de8-4129-912c-361040f6d66a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import seaborn as sns
df = pd.read_csv("Student_Mental_health.csv")
sns.histplot(df["What is your CGPA?"], bins=20, color="yellow")
plt.title("Histogram of CGPA")
plt.show()

# %%
df["Anxiety_num"]= df["Do you have Anxiety?"].map({"Yes":1, "No":0})

anxiety_by_gender = df.groupby("Choose your gender")["Anxiety_num"].mean().reset_index()

sns.barplot(x="Choose your gender", y="Anxiety_num", data=df, palette="Reds")
plt.title("Proportion of Students with Anxiety by Gender")
plt.ylabel("Proportion with Anxiety")
plt.show()
# Out:
# /tmp/ipython-input-2992073351.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Choose your gender", y="Anxiety_num", data=df, palette="Reds")

# %%
df["Panic_num"] = df["Do you have Panic attack?"].map({"Yes":1, "No": 0})
panic_by_age = df.groupby("Age")["Panic_num"].mean().reset_index()

sns.lmplot(x="Age", y="Panic_num", data=df, aspect=1.5, height=5)
plt.title("Exploring the Relationship Between Age and Panic Attacks")
plt.show()
